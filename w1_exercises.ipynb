# %%
import pandas as pd

data = {
    "Name": [
        "Alice", "Bob", "Charlie", "David", "Evelyn",
        "Frank", "Grace", "Henry", "Isla", "Jack",
        "Karen", "Leo", "Mia", "Noah", "Olivia",
        "Paul", "Quinn", "Ruby", "Sam", "Tina"
    ],
    "Age": [25, 32, 37, 29, 41, 28, 34, 45, 26, 31, 39, 27, 33, 36, 30, 42, 24, 38, 35, 29],
    "Department": [
        "HR", "Engineering", "Sales", "Marketing", "Engineering",
        "Finance", "Support", "Operations", "HR", "Sales",
        "Engineering", "Support", "Marketing", "Finance", "Operations",
        "Engineering", "HR", "Sales", "Support", "Marketing"
    ],
    "Salary": [
        50000, 75000, 62000, 58000, 80000,
        54000, 52000, 70000, 51000, 64000,
        82000, 53000, 60000, 56000, 68000,
        79000, 49500, 65500, 54500, 61000
    ],
}

df = pd.DataFrame(data)

# %%
# Section 1: Pandas: A Data Analyst's Best Friend

### Exercise 1
#View the first five rows of the DataFrame.
df.head()
# Out:
#       Name  Age   Department  Salary
# 0    Alice   25           HR   50000
# 1      Bob   32  Engineering   75000
# 2  Charlie   37        Sales   62000
# 3    David   29    Marketing   58000
# 4   Evelyn   41  Engineering   80000

# %%
### Exercise 2
#View the last five rows of the DataFrame.
df.tail()
# Out:
#      Name  Age   Department  Salary
# 15   Paul   42  Engineering   79000
# 16  Quinn   24           HR   49500
# 17   Ruby   38        Sales   65500
# 18    Sam   35      Support   54500
# 19   Tina   29    Marketing   61000

# %%
### Exercise 3
#Get basic info about the DataFrame.
df.info()

### Exercise 4
#Check the shape of the DataFrame.
df.shape
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        20 non-null     str
#  1   Age         20 non-null     int64
#  2   Department  20 non-null     str
#  3   Salary      20 non-null     int64
# dtypes: int64(2), str(2)
# memory usage: 772.0 bytes
# (20, 4)

# %%
import pandas as pd

# Load Titanic dataset
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)

# Preview the data
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
### Exercise 1
#Use `.loc` to get the name and age of the passenger with index 12.
print(df.loc[12, ["Name", "Age"]])
# Out:
# Name    Saundercock, Mr. William Henry
# Age                               20.0
# Name: 12, dtype: object

# %%
### Exercise 2
#Use `.iloc` to get the first 5 rows and first 3 columns.
print(df.iloc[0:5, 0:3])
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3

# %%
### Exercise 3
#Use `.loc` to get all passengers in 1st class who are female.
print(df.loc[(df["Sex"] == "female") & (df["Pclass"] == 1)])
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 1        0  PC 17599   71.2833   C85        C
# 3        0    113803   53.1000  C123        S
# 11       0    113783   26.5500  C103        S
# 31       0  PC 17569  146.5208   B78        C
# 52       0  PC 17572   76.7292   D33        C
# ..     ...       ...       ...   ...      ...
# 856      1     36928  164.8667   NaN        S
# 862      0     17466   25.9292   D17        S
# 871      1     11751   52.5542   D35        S
# 879      1     11767   83.1583   C50        C
# 887      0    112053   30.0000   B42        S
#
# [94 rows x 12 columns]

# %%
### Exercise 4
#Use `.iloc` to get the age of the 10th passenger (by position).

print(df.iloc[9]["Age"])
# Out:
# 14.0

# %%
### Exercise 5
#Use `.loc` to get the `Fare` and `Survived` values for passengers with index 100 to 105.
print(df.loc[100:105, ["Fare", "Survived"]])
# Out:
#         Fare  Survived
# 100   7.8958         0
# 101   7.8958         0
# 102  77.2875         0
# 103   8.6542         0
# 104   7.9250         0
# 105   7.8958         0

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)


### Exercise 1
#Summarize the numeric columns.
print(df.describe())



### Exercise 2
#Use `.value_counts()` to see counts for embarkation ports.
print("\nValue Counts for Embarked")
print(df.value_counts("Embarked"))

### Exercise 3
#Use `.value_counts()` to count passenger classes.
print("\nValue Counts for Pclass")
print(df.value_counts("Pclass"))

### Exercise 4
#Show the average (mean) age of passengers.
print("\nAverage Age of Passenger")
print(df["Age"].mean())

### Exercise 5
#Show the maximum fare paid.
print("\nMaximum Fare paid")
print(df["Fare"].max())

### Exercise 6
#Show how many unique names are in the dataset.
print("\nHow many unique names")
print(df["Name"].nunique())

### Exercise 7
#Show counts for values in the `Sex` column.
print("\nValue Counts for Sex")
print(df.value_counts("Sex"))

### Exercise 8
#Show how many unique values are in each column.
print("\nUnique Values for Each Column")
print(df.nunique())

### ADDED \n and some headers to make the output easier to read
# it was very annoying to look at when smooshed together
# but i could not keep adding cell blocks.... 

#forgive me for it taking me this long to make this easier and more legible for you (whoever is grading this)
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
#
# Value Counts for Embarked
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64
#
# Value Counts for Pclass
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
#
# Average Age of Passenger
# 29.69911764705882
#
# Maximum Fare paid
# 512.3292
#
# How many unique names
# 891
#
# Value Counts for Sex
# Sex
# male      577
# female    314
# Name: count, dtype: int64
#
# Unique Values for Each Column
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
# Section 2: Clean & Tidy Data

import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Charlie", "David"],
    "Age": [25, 30, 35, 40],
    "City": ["NYC", "LA", "Chicago", "Miami"],
    "Email": ["a@example.com", "b@example.com", "c@example.com", "d@example.com"],
}

df = pd.DataFrame(data)

### Exercise 1
#Drop the `Email` column and store the result in a new variable.
print("\nDropping the email column, but it's stored as a new variable")
df_no_email = df.drop("Email", axis=1)
print(df_no_email)

### Exercise 2
#Drop the row with index `2` in place.
print("\nDropping row with index 2")
df.drop(2, inplace=True)
print(df)

## i did this in my file previously and based off the output it seems like i need to do it here again
df = pd.DataFrame(data)

### Exercise 3
#Drop the `City` and `Email` columns, and assign the result back to `df`.
print("\nDropping the City and Email Column")
df = df.drop(["City", "Email"], axis=1)
print(df)

### Exercise 4
#Drop the first and last row, and store the result in `df_trimmed`.
print("\nDropping first and last row!")
df_trimmed = df.drop([df.index[0], df.index[-1]])
print(df_trimmed)
# Out:
# Dropping the email column, but it's stored as a new variable
#       Name  Age     City
# 0    Alice   25      NYC
# 1      Bob   30       LA
# 2  Charlie   35  Chicago
# 3    David   40    Miami
#
# Dropping row with index 2
#     Name  Age   City          Email
# 0  Alice   25    NYC  a@example.com
# 1    Bob   30     LA  b@example.com
# 3  David   40  Miami  d@example.com
#
# Dropping the City and Email Column
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40
#
# Dropping first and last row!
#       Name  Age
# 1      Bob   30
# 2  Charlie   35

# %%
## Exercise Set 2: Missing Data


import pandas as pd
import numpy as np

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Age": [25, np.nan, 35, 40, None],
    "City": ["NYC", "LA", None, "Miami", "Boston"],
}

df = pd.DataFrame(data)


### Exercise 1
#View the first 5 rows of the DataFrame.
print("First 5 rows")
print(df.head())

### Exercise 2
#Show where values are missing.
print("\nMissing Values:")
print(df.isnull())

### Exercise 3
#Count missing values by column.
print("\n Missing Values by Column")
print(df.isnull().sum())

### Exercise 4
#Drop rows with missing data.
print("\nDrop rows with missing data")
print(df.dropna())

#no exercise 5
#in my previous file i reset the dataframe here

df = pd.DataFrame(data)

### Exercise 6
#Drop columns with missing data.
print("\nDrop columns with missing data")
print(df.dropna(axis=1))

#no exercise 5
#going to do this again because right now we just have a list of names (or a series, techincally?)
df = pd.DataFrame(data)

### Exercise 8
#Fill missing `Age` values with the mean.
print("\nMissing age values will be replaced with the average age")
df['Age'] = df["Age"].fillna(df["Age"].mean())
print(df)

### Exercise 9
#Fill missing `City` values with `"Unknown"
print("\nMissing City values will be replaced with unkown")
df['City'] = df["City"].fillna("Unknown")
print(df)
# Out:
# First 5 rows
#       Name   Age    City
# 0    Alice  25.0     NYC
# 1      Bob   NaN      LA
# 2  Charlie  35.0     NaN
# 3    David  40.0   Miami
# 4      Eva   NaN  Boston
#
# Missing Values:
#     Name    Age   City
# 0  False  False  False
# 1  False   True  False
# 2  False  False   True
# 3  False  False  False
# 4  False   True  False
#
#  Missing Values by Column
# Name    0
# Age     2
# City    1
# dtype: int64
#
# Drop rows with missing data
#     Name   Age   City
# 0  Alice  25.0    NYC
# 3  David  40.0  Miami
#
# Drop columns with missing data
#       Name
# 0    Alice
# 1      Bob
# 2  Charlie
# 3    David
# 4      Eva
#
# Missing age values will be replaced with the average age
#       Name        Age    City
# 0    Alice  25.000000     NYC
# 1      Bob  33.333333      LA
# 2  Charlie  35.000000     NaN
# 3    David  40.000000   Miami
# 4      Eva  33.333333  Boston
# Missing City values will be replaced with unkown
#       Name        Age     City
# 0    Alice  25.000000      NYC
# 1      Bob  33.333333       LA
# 2  Charlie  35.000000  Unknown
# 3    David  40.000000    Miami
# 4      Eva  33.333333   Boston

# %%
## Exercise Set 3: Duplicates

import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Charlie", "Alice", "Bob", "Diana"],
    "Age": [25, 30, 35, 25, 30, 40],
    "City": ["NYC", "LA", "SF", "NYC", "LA", "NYC"],
}

df = pd.DataFrame(data)

### Exercise 1
#Find which rows are duplicates across all columns.
print("\nDuplicated rows (True if row is a duplicate of an earlier one):")
print(df.duplicated())

### Exercise 2
#Drop duplicate rows, keeping the first occurrence.
print("\nDataFrame with duplicates dropped (keep='first'):")
print(df.drop_duplicates(keep='first'))

##Gotta reset again

df = pd.DataFrame(data)

### Exercise 3
#Drop duplicate rows, keeping only the last occurrence.
print("\nDataFrame with duplicates dropped (keep='last'):")
print(df.drop_duplicates(keep='last'))

##one more time!
df = pd.DataFrame(data)

### Exercise 4
#Drop all duplicates, removing both the original and duplicate rows.
print("\nDataFrame with ALL duplicates removed (keep=False):")
print(df.drop_duplicates(keep=False))
# Out:
# Duplicated rows (True if row is a duplicate of an earlier one):
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# dtype: bool
#
# DataFrame with duplicates dropped (keep='first'):
#       Name  Age City
# 0    Alice   25  NYC
# 1      Bob   30   LA
# 2  Charlie   35   SF
# 5    Diana   40  NYC
#
# DataFrame with duplicates dropped (keep='last'):
#       Name  Age City
# 2  Charlie   35   SF
# 3    Alice   25  NYC
# 4      Bob   30   LA
# 5    Diana   40  NYC
#
# DataFrame with ALL duplicates removed (keep=False):
#       Name  Age City
# 2  Charlie   35   SF
# 5    Diana   40  NYC

# %%
# Section 3: Data Wrangling Essentials


## Exercise Set 1: Renaming Columns
import pandas as pd

data = {
    "fname": ["Alice", "Bob", "Charlie"],
    "lname": ["Smith", "Jones", "Brown"],
    "ctry": ["USA", "Canada", "UK"],
}

df = pd.DataFrame(data)


### Exercise 1
#Change `fname` to `FirstName` and `lname` to `LastName`.
print("\nLet's make these column names better!")
df.rename(columns={
    "fname": "FirstName",
    "lname": "LastName"
}, inplace=True)

print(df)

### Exercise 2
#Change all column names to: `['FirstName', 'LastName', 'Country']`

print("\n2. All column names changed:")
df.columns = ["FirstName", "LastName", "Country"]
#firstname and lastname are already changed but this is how youd do all the column names
print(df)
# Out:
# Let's make these column names better!
#   FirstName LastName    ctry
# 0     Alice    Smith     USA
# 1       Bob    Jones  Canada
# 2   Charlie    Brown      UK
#
# 2. All column names changed:
#   FirstName LastName Country
# 0     Alice    Smith     USA
# 1       Bob    Jones  Canada
# 2   Charlie    Brown      UK

# %%
## Exercise Set 2: Reordering Columns

import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Dept": ["HR", "Finance", "IT"],
    "Sal": [60000, 70000, 80000],
}

df = pd.DataFrame(data)

### Exercise 1
#Rename `Dept` to `Department` and `Sal` to `Salary`.
df.rename(columns={
    "Dept": "Department",
    "Sal": "Salary"
}, inplace=True)


### Exercise 2
#Reorder columns so `Salary` appears first, followed by `Name` and `Department`.
df= df[["Salary", "Name", "Department"]]

### Exercise 3
#Print the updated DataFrame.
print(df)
# Out:
#    Salary     Name Department
# 0   60000    Alice         HR
# 1   70000      Bob    Finance
# 2   80000  Charlie         IT

# %%
## Exercise Set 3: GroupBy and Agg

import pandas as pd

data = {
    "Store": ["A", "A", "A", "B", "B", "C", "C", "C", "C"],
    "Product": ["Apples", "Oranges", "Bananas", "Apples", "Bananas", "Oranges", "Apples", "Bananas", "Bananas"],
    "Sales": [100, 80, 90, 120, 110, 60, 95, 85, 75],
    "Profit": [30, 25, 20, 40, 35, 15, 32, 22, 18],
}

df = pd.DataFrame(data)
print(df.head())

### Exercise 1
#Group the data by `Store` and use `.agg()` to find the average `Sales` and average `Profit` for each store.
print("\nAverage Sales & Profit by Store:")
print(df.groupby("Store").agg({
    "Sales": "mean",
    "Profit": "mean"
}))


### Exercise 2
#Group by `Product` and get the maximum `Sales` and minimum `Profit`.
print("\n Maximum Sales & Minimum Profit by Product:")
print(df.groupby("Product").agg({
    "Sales": "max",
    "Profit": "min"
}))

### Exercise 3
#Group by `Store` and return the average `Sales` and maximum `Profit`, but name the columns `Avg_Sales` and `Max_Profit`.
print("\n Average Sales and Maximum Profit by Store:")
print(df.groupby("Store").agg(
    Avg_Sales=("Sales", "mean"),
    Max_Profit=("Profit", "max")
))

### Exercise 4
#BONUS: Group by both `Store` and `Product`, and find the total `Sales` using `.agg()`.

print("\nTotal Sales of each Product at each Store:")
print(df.groupby(["Store", "Product"]).agg({"Sales": "sum"}))

#couldnt figure this out the first time around
#i was missing a set of paranthesis!
#so happy to make this work!
# Out:
#   Store  Product  Sales  Profit
# 0     A   Apples    100      30
# 1     A  Oranges     80      25
# 2     A  Bananas     90      20
# 3     B   Apples    120      40
# 4     B  Bananas    110      35
#
# Average Sales & Profit by Store:
#         Sales  Profit
# Store
# A       90.00   25.00
# B      115.00   37.50
# C       78.75   21.75
#
#  Maximum Sales & Minimum Profit by Product:
#          Sales  Profit
# Product
# Apples     120      30
# Bananas    110      18
# Oranges     80      15
#
#  Average Sales and Maximum Profit by Store:
#        Avg_Sales  Max_Profit
# Store
# A          90.00          30
# B         115.00          40
# C          78.75          32
#
# Total Sales of each Product at each Store:
#                Sales
# Store Product
# A     Apples     100
#       Bananas     90
#       Oranges     80
# B     Apples     120
#       Bananas    110
# C     Apples      95
#       Bananas    160
#       Oranges     60

# %%
## Exercise Set 4: Joining


import pandas as pd

df_customers = pd.DataFrame({
    "CustomerName": ["Alice", "Bob", "Charlie"]
}, index=[101, 102, 103])

df_orders = pd.DataFrame({
    "OrderTotal": [250, 300, 400]
}, index=[101, 102, 103])


### Exercise 1
#Join `df_orders` to `df_customers` on the index.
print("Joining customers and orders dataframes:")
print(df_customers.join(df_orders))


### Exercise 2
#Add a new column to `df_customers` with city data from `df_cities`.

df_cities = pd.DataFrame({
    'City': ['NYC', 'LA', 'Chicago']
}, index=[101, 102, 103])
print("\nWhere are these customers from?!?!")
print(pd.concat([df_customers, df_cities], axis=1))
# this is how i did it originally but here's another way:
print("\nAnother way to see where the customers are from:")
print(df_customers.join(df_cities))
# Out:
# Joining customers and orders dataframes:
#     CustomerName  OrderTotal
# 101        Alice         250
# 102          Bob         300
# 103      Charlie         400
#
# Where are these customers from?!?!
#     CustomerName     City
# 101        Alice      NYC
# 102          Bob       LA
# 103      Charlie  Chicago
#
# Another way to see where the customers are from:
#     CustomerName     City
# 101        Alice      NYC
# 102          Bob       LA
# 103      Charlie  Chicago
